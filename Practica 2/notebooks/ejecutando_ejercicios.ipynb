# %%
import sys

# %%
sys.path.append('../src')

# %%
from ejercicio1 import stats

# %%
stats()
# Out:
# Total de lineas: 19
# Total de palabras: 137
# Promedio de palabras por linea: 7.21
#
# Líneas por encima del promedio (7.21) palabras):
#  - "    Special cases aren't special enough to break the rules." (9 palabras)
#  - "    In the face of ambiguity, refuse the temptation to guess." (10 palabras)
#  - "    There should be one-- and preferably only one --obvious way to do it." (13 palabras)
#  - "    Although that way may not be obvious at first unless you're Dutch." (12 palabras)
#  - "    Although never is often better than *right* now." (8 palabras)
#  - "    If the implementation is hard to explain, it's a bad idea." (11 palabras)
#  - "    If the implementation is easy to explain, it may be a good idea." (13 palabras)
#  - "    Namespaces are one honking great idea -- let's do more of those!" (12 palabras)

# %%
import ejercicio2

# %%
ejercicio2.time_playlist()
# Out:
# Duracion total: 46m 53s
# Cancion más larga: "Stairway to Heaven" (8:02)
# Cancion más corta: "Imagine" (3:07)

# %%
import ejercicio3

# %%
ejercicio3.spoiler()
# Out:
#     ** película sigue a un grupo de astronautas que viajan a *****
#     en una misión de rescate. El capitán ****** lidera al equipo
#     a través de tormentas solares y fallos en el sistema de navegación. Al llegar
#     a ***** descubren que ** base está abandonada y los suministros
#     destruidos. ****** decide sacrificar ** nave nodriza para salvar
#     al equipo y logran volver a ** Tierra en una cápsu** de emergencia.
#     El final revela que ****** sobrevivió gracias a un pasaje secreto.

# %%
import ejercicio4

# %%
ejercicio4.validation_mail()
# Out:
# El email es válido.

# %%
import ejercicio5

# %%
ejercicio5.calculator()
# Out:
# Costo del envio: $4500

# %%
import ejercicio6
# Out:
# Hashtags trending (más de una aparición):
# #Python: 3
# #Programación: 3
# #InteligenciaArtificial: 3
# #Motivación: 2
# #SerieAdicta: 2
# #Tecnología: 2
# Total de hashtags únicos: 13

# %%
import ejercicio7

# %%
ejercicio7.amigo_invisible()
# Out:
# Sorteo de amigo invisible:
# Jugador 1 → Jugador 2
# Jugador 2 → Jugador 4
# Jugador 4 → Jugador 3
# Jugador 3 → Jugador 1
