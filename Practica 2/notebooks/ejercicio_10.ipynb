# %%
import sys
sys.path.append('../src')

# %%
import ejercicio10

# %%
ejercicio10.ranking()
# Out:
# Ronda 1 - Entrada
#  Ganador: Camila (26 pts)
#
# Tabla de posiciones:
# Cocinero: Camila
# Puntaje: 26
# Rondas Ganadas: 1
# Mejor Ronda: 26
# Promedio: 26.0
#
# Cocinero: Valentina
# Puntaje: 24
# Rondas Ganadas: 0
# Mejor Ronda: 24
# Promedio: 24.0
#
# Cocinero: Lucía
# Puntaje: 24
# Rondas Ganadas: 0
# Mejor Ronda: 24
# Promedio: 24.0
#
# Cocinero: Mateo
# Puntaje: 22
# Rondas Ganadas: 0
# Mejor Ronda: 22
# Promedio: 22.0
#
# Cocinero: Santiago
# Puntaje: 19
# Rondas Ganadas: 0
# Mejor Ronda: 19
# Promedio: 19.0
#
# Ronda 2 - Plato principal
#  Ganador: Valentina (26 pts)
#
# Tabla de posiciones:
# Cocinero: Valentina
# Puntaje: 50
# Rondas Ganadas: 1
# Mejor Ronda: 26
# Promedio: 25.0
#
# Cocinero: Mateo
# Puntaje: 46
# Rondas Ganadas: 0
# Mejor Ronda: 24
# Promedio: 23.0
#
# Cocinero: Camila
# Puntaje: 46
# Rondas Ganadas: 1
# Mejor Ronda: 26
# Promedio: 23.0
#
# Cocinero: Lucía
# Puntaje: 46
# Rondas Ganadas: 0
# Mejor Ronda: 24
# Promedio: 23.0
#
# Cocinero: Santiago
# ...
